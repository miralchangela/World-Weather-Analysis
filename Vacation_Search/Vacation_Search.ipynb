# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map.
# ----
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Google API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame, retrieve the latitude and longitude of each city to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, skip to the next city.
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Review the formatting template provided that you'll use to add an information box to each marker in the map. In the pop-up for each city you'll add:
#
#     1. The city name.
#
#     2. The country code.
#
#     3. The weather description and maximum temperature for the city.
#
# 15. Review the provided list comprehension code to retrieve the city data from each row, which will then be added to the formatting template and saved in the `hotel_info` list.
#
# 16. Use the provided code snippet to retrieve the latitude and longitude from each row and store them in a new DataFrame called `locations`.
#
# 17. Refactor your previous marker layer map code to create a marker layer map that will have pop-up markers for each city on the map.
#
# 18. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Google API key is imported correctly.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import Google API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame.

# %%
# Set the file path to import the WeatherPy_database.csv file
file_path = "../Weather_Database/WeatherPy_database.csv"

# Load the CSV file into a Pandas DataFrame
city_data_df = pd.read_csv(file_path)

# Display sample data
city_data_df.head(10)
# Out:
#    City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0         Luderitz     NaN -26.6481   15.1594     57.72        84
# 1        1  Arraial Do Cabo      BR -22.9661  -42.0278     69.76        78
# 2        2       Winchester      GB  51.0651   -1.3187     53.65        80
# 3        3           Albany      US  42.6001  -73.9662     62.46        60
# 4        4         Cam Ranh      VN  11.9214  109.1591     80.56        78
# 5        5       Georgetown      MY   5.4112  100.3354     80.89        91
# 6        6         San Jose      US  37.3394 -121.8950     82.92        53
# 7        7       Alamogordo      US  32.8995 -105.9603     80.40        28
# 8        8           Cairns      AU -16.9167  145.7667     69.75        83
# 9        9             Aksu      CN  41.1231   80.2644     66.38        27
#
#    Cloudiness  Wind Speed Current Description
# 0           0       16.46           clear sky
# 1         100        9.22     overcast clouds
# 2           0        4.61           clear sky
# 3           4        1.99           clear sky
# 4          40       10.36    scattered clouds
# 5          20        2.30        thunderstorm
# 6          20        4.00          few clouds
# 7           0        5.75           clear sky
# 8          14        4.61          few clouds
# 9         100        4.43     overcast clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.

# %%
# Prompt the user to enter the minimum temperature criteria
min_temp = float(input("what is minimum temperature you want for your trip?"))

# Prompt the user to enter the maximum temperature criteria
max_temp = float(input("what is maxmum temperature you want for your trip?"))
# Out:
# what is minimum temperature you want for your trip?20
# what is maxmum temperature you want for your trip?70

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected.

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc Pandas function
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] >= min_temp) & (city_data_df["Max Temp"] <= max_temp)]
                                    
# Display sample dat
preferred_cities_df.head()
# Out:
#    City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0         Luderitz     NaN -26.6481   15.1594     57.72        84
# 1        1  Arraial Do Cabo      BR -22.9661  -42.0278     69.76        78
# 2        2       Winchester      GB  51.0651   -1.3187     53.65        80
# 3        3           Albany      US  42.6001  -73.9662     62.46        60
# 8        8           Cairns      AU -16.9167  145.7667     69.75        83
#
#    Cloudiness  Wind Speed Current Description
# 0           0       16.46           clear sky
# 1         100        9.22     overcast clouds
# 2           0        4.61           clear sky
# 3           4        1.99           clear sky
# 8          14        4.61          few clouds

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.

# %%
# Drop any empty rows in the preferred_cities_df DataFrame and create a new DataFrame.
clean_travel_cities = preferred_cities_df.dropna()

# Display sample data
clean_travel_cities
# Out:
#      City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 1          1  Arraial Do Cabo      BR -22.9661  -42.0278     69.76        78
# 2          2       Winchester      GB  51.0651   -1.3187     53.65        80
# 3          3           Albany      US  42.6001  -73.9662     62.46        60
# 8          8           Cairns      AU -16.9167  145.7667     69.75        83
# 9          9             Aksu      CN  41.1231   80.2644     66.38        27
# ..       ...              ...     ...      ...       ...       ...       ...
# 686      686        Kalamazoo      US  42.2506  -85.5500     62.51        39
# 687      687          Chapais      CA  49.7834  -74.8492     49.78        52
# 688      688      Vilkaviskis      LT  54.6517   23.0322     48.52        81
# 690      690          Mozelos      PT  41.8677   -8.3978     61.88        86
# 692      692         Okulovka      RU  58.4008   33.2908     45.95        97
#
#      Cloudiness  Wind Speed Current Description
# 1           100        9.22     overcast clouds
# 2             0        4.61           clear sky
# 3             4        1.99           clear sky
# 8            14        4.61          few clouds
# 9           100        4.43     overcast clouds
# ..          ...         ...                 ...
# 686           1        1.68           clear sky
# 687          99        9.06     overcast clouds
# 688          91        7.43     overcast clouds
# 690           2        4.61           clear sky
# 692         100        6.89     overcast clouds
#
# [359 rows x 10 columns]

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".

# %%
# Create DataFrame called hotel_df by copying some columns from the clean_travel_cities DataFrame.
hotel_df = clean_travel_cities[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# Display sample data
hotel_df.head(10)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng
# 1   Arraial Do Cabo      BR     69.76     overcast clouds -22.9661  -42.0278
# 2        Winchester      GB     53.65           clear sky  51.0651   -1.3187
# 3            Albany      US     62.46           clear sky  42.6001  -73.9662
# 8            Cairns      AU     69.75          few clouds -16.9167  145.7667
# 9              Aksu      CN     66.38     overcast clouds  41.1231   80.2644
# 10          Ushuaia      AR     55.06          few clouds -54.8000  -68.3000
# 11          Mataura      NZ     42.48    scattered clouds -46.1927  168.8643
# 13         Hermanus      ZA     58.80     overcast clouds -34.4187   19.2345
# 14       Chokurdakh      RU     22.12     overcast clouds  70.6333  147.9167
# 15      Lukovetskiy      RU     34.18     overcast clouds  64.2956   41.9211

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.

# %%
# Add a new empty column, "Hotel Name", to the hotel_df DataFrame
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head(10)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 1   Arraial Do Cabo      BR     69.76     overcast clouds -22.9661  -42.0278
# 2        Winchester      GB     53.65           clear sky  51.0651   -1.3187
# 3            Albany      US     62.46           clear sky  42.6001  -73.9662
# 8            Cairns      AU     69.75          few clouds -16.9167  145.7667
# 9              Aksu      CN     66.38     overcast clouds  41.1231   80.2644
# 10          Ushuaia      AR     55.06          few clouds -54.8000  -68.3000
# 11          Mataura      NZ     42.48    scattered clouds -46.1927  168.8643
# 13         Hermanus      ZA     58.80     overcast clouds -34.4187   19.2345
# 14       Chokurdakh      RU     22.12     overcast clouds  70.6333  147.9167
# 15      Lukovetskiy      RU     34.18     overcast clouds  64.2956   41.9211
#
#    Hotel Name
# 1
# 2
# 3
# 8
# 9
# 10
# 11
# 13
# 14
# 15

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.

# %%
# Review the parameters to search for a hotel
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame, retrieve the latitude and longitude of each city to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, skip to the next city.

# %%
# Iterate through the hotel DataFrame 
import numpy as np
for index, row in hotel_df.iterrows():
    # Fetch latitude and longitude from the DataFrame
    lat =row["Lat"]
    lng = row["Lng"]
    
    # Add the latitude and longitude as parameters to the params dictionary
    params["location"] = f"{lat},{lng}"
    
    # Set up the base URL for the Google Directions API to get JSON data
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"  
  
    # Make an API request and retrieve the JSON data from the hotel search
    response = requests.get(base_url, params=params)
    #print(response.url)
    hotels = response.json()
    # Print the json (pretty printed)
    #print(json.dumps(places_data, indent=4, sort_keys=True))
    # Get the first hotel from the results and store the name, if a hotel isn't found skip the city
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        hotel_df.loc[index, "Hotel Name"] = np.nan
        print("Hotel not found... skipping.")
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-22.9661%2C-42.0278
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=51.0651%2C-1.3187
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=42.6001%2C-73.9662
# Hotel not found... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-16.9167%2C145.7667
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=41.1231%2C80.2644
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-54.8%2C-68.3
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-46.1927%2C168.8643
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-34.4187%2C19.2345
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=70.6333%2C147.9167
# Hotel not found... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=64.2956%2C41.9211
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=65.6145%2C-37.6368
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=69.4541%2C-133.0374
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=78.2186%2C15.6401
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=42.097%2C-79.2353
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=60.9167%2C-46.05
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=55.7435%2C-97.8558
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-53.15%2C-70.9167
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-32.2667%2C150.9
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=34.0667%2C136.2
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-35.1667%2C173.1667
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-25.2406%2C130.9889
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-33.6971%2C-53.4616
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-42.7826%2C147.0587
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=64.8378%2C-147.7164
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=73.5069%2C80.5464
# Hotel not found... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=34.6667%2C138.95
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-33.5906%2C26.891
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=71.2906%2C-156.7887
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-33.65%2C115.3333
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-46.6%2C168.3333
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-13.7%2C-76.2167
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=47.8043%2C67.7144
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-42.8794%2C147.3294
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=65.7%2C82.4667
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=51.5%2C156.5167
# Hotel not found... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=60.8953%2C131.9608
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-27.8549%2C26.3658
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-33.0153%2C27.9116
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=57.79%2C-152.4072
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-33.918%2C25.5701
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=63.7256%2C8.834
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=50.0334%2C-66.8654
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=65.5833%2C-171.0
# Hotel not found... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=40.1629%2C-8.3327
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-21.3585%2C55.7679
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=41.7597%2C86.1469
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-43.5333%2C172.6333
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=66.5606%2C67.7975
# Hotel not found... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=50.2334%2C-63.5986
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=59.0556%2C80.8572
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-33.9258%2C18.4232
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-24.7911%2C-50.0119
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=7.9986%2C124.2928
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=55.219%2C75.9828
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-15.1961%2C12.1522
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=47.6666%2C-52.7314
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=59.7035%2C30.7861
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=68.75%2C161.3
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-46.2817%2C169.8464
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=48.9329%2C-125.5528
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=41.2835%2C-70.0995
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=45.1334%2C-71.7991
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=33.0833%2C-16.3333
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=71.9167%2C114.0833
# Hotel not found... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-34.7333%2C135.8667
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=60.05%2C69.9
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-34.5322%2C20.0403
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=45.0617%2C-83.4327
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=44.0787%2C-80.2041
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-24.8667%2C113.6333
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=71.9667%2C102.5
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=48.0388%2C38.5969
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-36.3667%2C146.3333
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=35.7333%2C140.8333
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=70.0311%2C20.9714
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=34.1667%2C77.5833
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=61.2767%2C108.0108
# Hotel not found... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=66.3167%2C-179.1667
# Hotel not found... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=62.456%2C-114.3525
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=63.05%2C179.3167
# Hotel not found... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=21.65%2C-101.5
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=52.6333%2C9.2167
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=46.4333%2C26.4
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=61.5814%2C-149.4394
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-32.5%2C137.7667
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=40.3281%2C-79.6153
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-8.9833%2C33.9667
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=33.194%2C-82.5271
# Hotel not found... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=22.7886%2C100.9748
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=51.9333%2C116.6333
# Hotel not found... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=45.1559%2C29.6536
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-26.8241%2C-65.2226
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-6.379%2C-78.8157
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-25.1667%2C45.05
# Hotel not found... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=51.2833%2C91.5833
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=56.2942%2C46.3039
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=64.2539%2C-15.2082
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=57.2824%2C35.2262
# Hotel not found... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=51.0736%2C132.5642
# Hotel not found... skipping.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=56.45%2C138.1667
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=63.4427%2C-20.2734
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=55.1001%2C-105.2842
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-33.0117%2C17.9442
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=69.2296%2C17.9811
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=40.1774%2C122.1228
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-44.7%2C169.15
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=41.2054%2C-76.0049
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-36.7667%2C144.2833
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=44.3583%2C77.9753
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=54.0524%2C-128.6534
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=60.5672%2C6.9187
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-10.7%2C-77.7833
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=50.6114%2C105.3196
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=47.2456%2C47.0281
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=47.9077%2C106.8832
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=69.3143%2C16.1194
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-32.25%2C148.6167
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-25.2986%2C152.8535
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=-37.8333%2C140.7667
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=42.2506%2C-85.55
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=49.7834%2C-74.8492
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=54.6517%2C23.0322
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=41.8677%2C-8.3978
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&type=lodging&key=AIzaSyBtaRIUVr9jFpjD7jF_0wgXJPX51Y3aXI0&location=58.4008%2C33.2908

# %%
# Display sample data
hotel_df
# Out:
#                 City Country  Max Temp Current Description      Lat       Lng  \
# 1    Arraial Do Cabo      BR     69.76     overcast clouds -22.9661  -42.0278
# 2         Winchester      GB     53.65           clear sky  51.0651   -1.3187
# 3             Albany      US     62.46           clear sky  42.6001  -73.9662
# 8             Cairns      AU     69.75          few clouds -16.9167  145.7667
# 9               Aksu      CN     66.38     overcast clouds  41.1231   80.2644
# ..               ...     ...       ...                 ...      ...       ...
# 686        Kalamazoo      US     62.51           clear sky  42.2506  -85.5500
# 687          Chapais      CA     49.78     overcast clouds  49.7834  -74.8492
# 688      Vilkaviskis      LT     48.52     overcast clouds  54.6517   23.0322
# 690          Mozelos      PT     61.88           clear sky  41.8677   -8.3978
# 692         Okulovka      RU     45.95     overcast clouds  58.4008   33.2908
#
#                                  Hotel Name
# 1                       Pousada Porto Praia
# 2                            Lainston House
# 3                                       NaN
# 8                     Mantra Trilogy Cairns
# 9                      Pudong Holiday Hotel
# ..                                      ...
# 686       Four Points by Sheraton Kalamazoo
# 687                          Hôtel Opémiska
# 688                Širvintos viešbutis, UAB
# 690  Casa do Rio Vez - Alojamento de Charme
# 692                          Motel' Flagman
#
# [359 rows x 7 columns]

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.

# %%
hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359 entries, 1 to 692
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 359 non-null    object
#  1   Country              359 non-null    object
#  2   Max Temp             359 non-null    float64
#  3   Current Description  359 non-null    object
#  4   Lat                  359 non-null    float64
#  5   Lng                  359 non-null    float64
#  6   Hotel Name           320 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 30.5+ KB

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna(axis="index", how="any")
# Display sample data
clean_hotel_df.head(10)
# Out:
#                City Country  Max Temp Current Description      Lat       Lng  \
# 1   Arraial Do Cabo      BR     69.76     overcast clouds -22.9661  -42.0278
# 2        Winchester      GB     53.65           clear sky  51.0651   -1.3187
# 8            Cairns      AU     69.75          few clouds -16.9167  145.7667
# 9              Aksu      CN     66.38     overcast clouds  41.1231   80.2644
# 10          Ushuaia      AR     55.06          few clouds -54.8000  -68.3000
# 11          Mataura      NZ     42.48    scattered clouds -46.1927  168.8643
# 13         Hermanus      ZA     58.80     overcast clouds -34.4187   19.2345
# 15      Lukovetskiy      RU     34.18     overcast clouds  64.2956   41.9211
# 17         Tasiilaq      GL     35.76     overcast clouds  65.6145  -37.6368
# 19      Tuktoyaktuk      CA     30.20     overcast clouds  69.4541 -133.0374
#
#                     Hotel Name
# 1          Pousada Porto Praia
# 2               Lainston House
# 8        Mantra Trilogy Cairns
# 9         Pudong Holiday Hotel
# 10             Albatross Hotel
# 11               Ellie's Villa
# 13  Misty Waves Boutique Hotel
# 15                 Provintsiya
# 17               The Red House
# 19        End of The Road Ltd.

# %% [markdown]
# **Note:** If the resulting DataFrame is empty, uncomment the following code to load sample data into the `clean_hotel_df`.

# %%
# In case of an empty DataFrame, load the sample data provided
# clean_hotel_df = pd.read_csv("WeatherPy_vacation-backup.csv")
# clean_hotel_df.head(10)

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.

# %%
# Set the file name.
output_data_file = "WeatherPy_vacation.csv"

# Create a CSV file by using the clean_hotel_df DataFrame
clean_hotel_df.to_csv(output_data_file , index_label = "City_ID")

# %% [markdown]
# ### Review the formatting template provided that you'll use to add an information box to each marker in the map.
#
# In the pop-up for each city you'll add:
#
# 1. The city name
#
# 2. The country code
#
# 3. The weather description and maximum temperature for the city

# %%
# Review the formatting template provided
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# %% [markdown]
# ## Review the provided list comprehension code to retrieve the city data from each row, which will then be added to the formatting template and saved in the `hotel_info` list.

# %%
# Get the data from each row in the clean_hotel_df DataFrame, add it to the formatting template, and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# Display sample data
hotel_info[:10]
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd>Pousada Porto Praia</dd>\n<dt>City</dt><dd>Arraial Do Cabo</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>overcast clouds and 69.76 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lainston House</dd>\n<dt>City</dt><dd>Winchester</dd>\n<dt>Country</dt><dd>GB</dd>\n<dt>Current Weather</dt><dd>clear sky and 53.65 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mantra Trilogy Cairns</dd>\n<dt>City</dt><dd>Cairns</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Weather</dt><dd>few clouds and 69.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pudong Holiday Hotel</dd>\n<dt>City</dt><dd>Aksu</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Current Weather</dt><dd>overcast clouds and 66.38 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Albatross Hotel</dd>\n<dt>City</dt><dd>Ushuaia</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Current Weather</dt><dd>few clouds and 55.06 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Ellie's Villa</dd>\n<dt>City</dt><dd>Mataura</dd>\n<dt>Country</dt><dd>NZ</dd>\n<dt>Current Weather</dt><dd>scattered clouds and 42.48 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Misty Waves Boutique Hotel</dd>\n<dt>City</dt><dd>Hermanus</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Current Weather</dt><dd>overcast clouds and 58.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Provintsiya</dd>\n<dt>City</dt><dd>Lukovetskiy</dd>\n<dt>Country</dt><dd>RU</dd>\n<dt>Current Weather</dt><dd>overcast clouds and 34.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Red House</dd>\n<dt>City</dt><dd>Tasiilaq</dd>\n<dt>Country</dt><dd>GL</dd>\n<dt>Current Weather</dt><dd>overcast clouds and 35.76 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>End of The Road Ltd.</dd>\n<dt>City</dt><dd>Tuktoyaktuk</dd>\n<dt>Country</dt><dd>CA</dd>\n<dt>Current Weather</dt><dd>overcast clouds and 30.2 °F</dd>\n</dl>\n']

# %% [markdown]
# ## Use the provided code snippet to retrieve the latitude and longitude from each row and store them in a new DataFrame called `locations`.

# %%
# Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# Display sample data
locations.head(10)
# Out:
#         Lat       Lng
# 1  -22.9661  -42.0278
# 2   51.0651   -1.3187
# 8  -16.9167  145.7667
# 9   41.1231   80.2644
# 10 -54.8000  -68.3000
# 11 -46.1927  168.8643
# 13 -34.4187   19.2345
# 15  64.2956   41.9211
# 17  65.6145  -37.6368
# 19  69.4541 -133.0374

# %% [markdown]
# ## Refactor your previous marker layer map code to create a marker layer map that will have pop-up markers for each city on the map.

# %%
# Add a marker layer for each city to the map. 
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
# Create a figure to add the Google map as a layer
fig.add_layer(markers)
# Display the figure containing the map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
