# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description =city_weather["weather"][0]["description"] 
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                           "Country": city_country
                         })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | luderitz
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | winchester
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | tambul
# City not found. Skipping...
# Processing Record 7 of Set 1 | cam ranh
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | san jose
# Processing Record 10 of Set 1 | alamogordo
# Processing Record 11 of Set 1 | cairns
# Processing Record 12 of Set 1 | aksu
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | benguela
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | chokurdakh
# Processing Record 18 of Set 1 | lukovetskiy
# Processing Record 19 of Set 1 | saucillo
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | salalah
# Processing Record 22 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 1 | tuktoyaktuk
# Processing Record 24 of Set 1 | longyearbyen
# Processing Record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 1 | ixtapa
# Processing Record 27 of Set 1 | ribeira grande
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | fare
# Processing Record 30 of Set 1 | narsaq
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | poum
# Processing Record 34 of Set 1 | half moon bay
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | muswellbrook
# Processing Record 37 of Set 1 | owase
# Processing Record 38 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 1 | ahipara
# Processing Record 40 of Set 1 | yulara
# Processing Record 41 of Set 1 | sultanpur
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | chuy
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | fairbanks
# Processing Record 47 of Set 1 | yialos
# City not found. Skipping...
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | etchoropo
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | shimoda
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | pio xii
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | gat
# Processing Record 10 of Set 2 | pisco
# Processing Record 11 of Set 2 | zhezkazgan
# Processing Record 12 of Set 2 | leningradskiy
# Processing Record 13 of Set 2 | hobart
# Processing Record 14 of Set 2 | krasnoselkup
# Processing Record 15 of Set 2 | ozernovskiy
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | faanui
# Processing Record 18 of Set 2 | coruripe
# Processing Record 19 of Set 2 | amga
# Processing Record 20 of Set 2 | wesselsbron
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | sistranda
# Processing Record 25 of Set 2 | port-cartier
# Processing Record 26 of Set 2 | mountain home
# Processing Record 27 of Set 2 | lavrentiya
# Processing Record 28 of Set 2 | lata
# Processing Record 29 of Set 2 | laguna
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | korla
# Processing Record 32 of Set 2 | christchurch
# Processing Record 33 of Set 2 | aksarka
# Processing Record 34 of Set 2 | kavieng
# Processing Record 35 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 36 of Set 2 | linfen
# Processing Record 37 of Set 2 | adrar
# Processing Record 38 of Set 2 | jerome
# Processing Record 39 of Set 2 | havre-saint-pierre
# Processing Record 40 of Set 2 | kargasok
# Processing Record 41 of Set 2 | hilo
# Processing Record 42 of Set 2 | sao filipe
# Processing Record 43 of Set 2 | cape town
# Processing Record 44 of Set 2 | castro
# Processing Record 45 of Set 2 | gerash
# Processing Record 46 of Set 2 | marawi
# Processing Record 47 of Set 2 | atuona
# Processing Record 48 of Set 2 | tatarsk
# Processing Record 49 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 2 | soma
# Processing Record 1 of Set 3 | labuhan
# Processing Record 2 of Set 3 | namibe
# Processing Record 3 of Set 3 | torbay
# Processing Record 4 of Set 3 | nikolskoye
# Processing Record 5 of Set 3 | erzin
# Processing Record 6 of Set 3 | cherskiy
# Processing Record 7 of Set 3 | abilene
# Processing Record 8 of Set 3 | muroto
# Processing Record 9 of Set 3 | avarua
# Processing Record 10 of Set 3 | bhigvan
# Processing Record 11 of Set 3 | atar
# Processing Record 12 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 3 | kaitangata
# Processing Record 14 of Set 3 | ucluelet
# Processing Record 15 of Set 3 | russell
# Processing Record 16 of Set 3 | salinopolis
# Processing Record 17 of Set 3 | nantucket
# Processing Record 18 of Set 3 | mahebourg
# Processing Record 19 of Set 3 | coaticook
# Processing Record 20 of Set 3 | praia da vitoria
# Processing Record 21 of Set 3 | samana
# Processing Record 22 of Set 3 | vanimo
# Processing Record 23 of Set 3 | viesca
# Processing Record 24 of Set 3 | golden
# Processing Record 25 of Set 3 | camacha
# Processing Record 26 of Set 3 | bengkulu
# Processing Record 27 of Set 3 | saskylakh
# Processing Record 28 of Set 3 | port lincoln
# Processing Record 29 of Set 3 | abnub
# Processing Record 30 of Set 3 | gornopravdinsk
# Processing Record 31 of Set 3 | bredasdorp
# Processing Record 32 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 3 | alpena
# Processing Record 35 of Set 3 | shelburne
# Processing Record 36 of Set 3 | beihai
# Processing Record 37 of Set 3 | kapaa
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | raga
# Processing Record 40 of Set 3 | khatanga
# Processing Record 41 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 3 | torez
# Processing Record 43 of Set 3 | wangaratta
# Processing Record 44 of Set 3 | asyut
# Processing Record 45 of Set 3 | hasaki
# Processing Record 46 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 3 | maragogi
# Processing Record 48 of Set 3 | celestun
# Processing Record 49 of Set 3 | skjervoy
# Processing Record 50 of Set 3 | saint george
# Processing Record 1 of Set 4 | leh
# Processing Record 2 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 3 of Set 4 | bambous virieux
# Processing Record 4 of Set 4 | yerbogachen
# Processing Record 5 of Set 4 | egvekinot
# Processing Record 6 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 4 | mazamari
# Processing Record 8 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 4 | yellowknife
# Processing Record 10 of Set 4 | beringovskiy
# Processing Record 11 of Set 4 | ocampo
# Processing Record 12 of Set 4 | eldikan
# City not found. Skipping...
# Processing Record 13 of Set 4 | nienburg
# Processing Record 14 of Set 4 | codrington
# Processing Record 15 of Set 4 | provideniya
# Processing Record 16 of Set 4 | butaritari
# Processing Record 17 of Set 4 | masaka
# Processing Record 18 of Set 4 | yarkovo
# Processing Record 19 of Set 4 | kaeo
# Processing Record 20 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 4 | talnakh
# Processing Record 22 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 4 | tucupita
# Processing Record 25 of Set 4 | texistepeque
# Processing Record 26 of Set 4 | lamar
# Processing Record 27 of Set 4 | tessalit
# Processing Record 28 of Set 4 | cayenne
# Processing Record 29 of Set 4 | auki
# Processing Record 30 of Set 4 | cabo san lucas
# Processing Record 31 of Set 4 | zemio
# Processing Record 32 of Set 4 | tarasovskiy
# Processing Record 33 of Set 4 | general roca
# Processing Record 34 of Set 4 | vila velha
# Processing Record 35 of Set 4 | liverpool
# Processing Record 36 of Set 4 | sawtell
# Processing Record 37 of Set 4 | general pico
# Processing Record 38 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 4 | concarneau
# Processing Record 40 of Set 4 | houma
# Processing Record 41 of Set 4 | nuevo progreso
# Processing Record 42 of Set 4 | souillac
# Processing Record 43 of Set 4 | benghazi
# Processing Record 44 of Set 4 | mozarlandia
# Processing Record 45 of Set 4 | whitehorse
# Processing Record 46 of Set 4 | saint-joseph
# Processing Record 47 of Set 4 | uspenka
# Processing Record 48 of Set 4 | bethel
# Processing Record 49 of Set 4 | maniitsoq
# Processing Record 50 of Set 4 | alibag
# Processing Record 1 of Set 5 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 2 of Set 5 | ponta do sol
# Processing Record 3 of Set 5 | mokhsogollokh
# Processing Record 4 of Set 5 | nanortalik
# Processing Record 5 of Set 5 | nome
# Processing Record 6 of Set 5 | ostrovnoy
# Processing Record 7 of Set 5 | katete
# Processing Record 8 of Set 5 | murgab
# Processing Record 9 of Set 5 | pacific grove
# Processing Record 10 of Set 5 | ulverstone
# Processing Record 11 of Set 5 | road town
# Processing Record 12 of Set 5 | norman wells
# Processing Record 13 of Set 5 | te anau
# Processing Record 14 of Set 5 | vieux-habitants
# Processing Record 15 of Set 5 | libertador general san martin
# Processing Record 16 of Set 5 | puerto ayora
# Processing Record 17 of Set 5 | victoria
# Processing Record 18 of Set 5 | lere
# Processing Record 19 of Set 5 | navahrudak
# Processing Record 20 of Set 5 | ion roata
# Processing Record 21 of Set 5 | meadow lake
# Processing Record 22 of Set 5 | acheng
# Processing Record 23 of Set 5 | lorengau
# Processing Record 24 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 5 | hamilton
# Processing Record 26 of Set 5 | bathsheba
# Processing Record 27 of Set 5 | nizhniy kuranakh
# Processing Record 28 of Set 5 | hauterive
# Processing Record 29 of Set 5 | upernavik
# Processing Record 30 of Set 5 | isangel
# Processing Record 31 of Set 5 | emerald
# Processing Record 32 of Set 5 | padang
# Processing Record 33 of Set 5 | calvinia
# Processing Record 34 of Set 5 | usinsk
# Processing Record 35 of Set 5 | alofi
# Processing Record 36 of Set 5 | teseney
# Processing Record 37 of Set 5 | faya
# Processing Record 38 of Set 5 | pevek
# Processing Record 39 of Set 5 | kisangani
# Processing Record 40 of Set 5 | portland
# Processing Record 41 of Set 5 | vostok
# Processing Record 42 of Set 5 | safaga
# Processing Record 43 of Set 5 | badou
# Processing Record 44 of Set 5 | isla mujeres
# Processing Record 45 of Set 5 | grand gaube
# Processing Record 46 of Set 5 | namatanai
# Processing Record 47 of Set 5 | caravelas
# Processing Record 48 of Set 5 | ararangua
# Processing Record 49 of Set 5 | wahpeton
# Processing Record 50 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 1 of Set 6 | phan thiet
# Processing Record 2 of Set 6 | simpang
# Processing Record 3 of Set 6 | alyangula
# Processing Record 4 of Set 6 | sancti spiritus
# Processing Record 5 of Set 6 | vardo
# Processing Record 6 of Set 6 | bowen
# Processing Record 7 of Set 6 | strezhevoy
# Processing Record 8 of Set 6 | mae hong son
# Processing Record 9 of Set 6 | makakilo city
# Processing Record 10 of Set 6 | szczytno
# Processing Record 11 of Set 6 | hualmay
# Processing Record 12 of Set 6 | flinders
# Processing Record 13 of Set 6 | rawson
# Processing Record 14 of Set 6 | berezovyy
# Processing Record 15 of Set 6 | timra
# Processing Record 16 of Set 6 | los llanos de aridane
# Processing Record 17 of Set 6 | puerto del rosario
# Processing Record 18 of Set 6 | yarada
# Processing Record 19 of Set 6 | redmond
# Processing Record 20 of Set 6 | iqaluit
# Processing Record 21 of Set 6 | lebu
# Processing Record 22 of Set 6 | mar del plata
# Processing Record 23 of Set 6 | dukat
# Processing Record 24 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 25 of Set 6 | wilson
# Processing Record 26 of Set 6 | concordia
# Processing Record 27 of Set 6 | keti bandar
# Processing Record 28 of Set 6 | geraldton
# Processing Record 29 of Set 6 | snezhnogorsk
# Processing Record 30 of Set 6 | dwarka
# Processing Record 31 of Set 6 | louth
# Processing Record 32 of Set 6 | bosaso
# Processing Record 33 of Set 6 | longjiang
# Processing Record 34 of Set 6 | mednogorskiy
# Processing Record 35 of Set 6 | raudeberg
# Processing Record 36 of Set 6 | solnechnyy
# Processing Record 37 of Set 6 | talara
# Processing Record 38 of Set 6 | erenhot
# Processing Record 39 of Set 6 | tautira
# Processing Record 40 of Set 6 | bubaque
# Processing Record 41 of Set 6 | sompeta
# Processing Record 42 of Set 6 | grindavik
# Processing Record 43 of Set 6 | gobabis
# Processing Record 44 of Set 6 | el balyana
# City not found. Skipping...
# Processing Record 45 of Set 6 | kabalo
# Processing Record 46 of Set 6 | saint-augustin
# Processing Record 47 of Set 6 | abu kamal
# Processing Record 48 of Set 6 | shingu
# Processing Record 49 of Set 6 | san cristobal
# Processing Record 50 of Set 6 | winnemucca
# Processing Record 1 of Set 7 | gorontalo
# Processing Record 2 of Set 7 | monchegorsk
# Processing Record 3 of Set 7 | nizhniy tsasuchey
# Processing Record 4 of Set 7 | bulungu
# Processing Record 5 of Set 7 | parana
# Processing Record 6 of Set 7 | yangambi
# Processing Record 7 of Set 7 | sitka
# Processing Record 8 of Set 7 | canutama
# Processing Record 9 of Set 7 | katherine
# Processing Record 10 of Set 7 | ust-nera
# Processing Record 11 of Set 7 | paamiut
# Processing Record 12 of Set 7 | sur
# Processing Record 13 of Set 7 | boffa
# Processing Record 14 of Set 7 | masuguru
# Processing Record 15 of Set 7 | yanam
# Processing Record 16 of Set 7 | lompoc
# Processing Record 17 of Set 7 | esperance
# Processing Record 18 of Set 7 | takoradi
# Processing Record 19 of Set 7 | olafsvik
# Processing Record 20 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 7 | kungurtug
# Processing Record 22 of Set 7 | ntchisi
# Processing Record 23 of Set 7 | hithadhoo
# Processing Record 24 of Set 7 | churapcha
# Processing Record 25 of Set 7 | huarmey
# Processing Record 26 of Set 7 | manaus
# Processing Record 27 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 7 | samarai
# Processing Record 29 of Set 7 | saint-pierre
# Processing Record 30 of Set 7 | anshun
# Processing Record 31 of Set 7 | mayumba
# Processing Record 32 of Set 7 | ambanja
# Processing Record 33 of Set 7 | nizhnyaya tura
# Processing Record 34 of Set 7 | barra patuca
# Processing Record 35 of Set 7 | soe
# Processing Record 36 of Set 7 | praia
# Processing Record 37 of Set 7 | husavik
# Processing Record 38 of Set 7 | alekseyevsk
# Processing Record 39 of Set 7 | kushmurun
# Processing Record 40 of Set 7 | hanna
# Processing Record 41 of Set 7 | sadabad
# Processing Record 42 of Set 7 | okaihau
# Processing Record 43 of Set 7 | meulaboh
# Processing Record 44 of Set 7 | odweyne
# Processing Record 45 of Set 7 | togur
# Processing Record 46 of Set 7 | severnyy
# Processing Record 47 of Set 7 | basco
# Processing Record 48 of Set 7 | tommot
# Processing Record 49 of Set 7 | melfort
# Processing Record 50 of Set 7 | tuatapere
# Processing Record 1 of Set 8 | beyneu
# Processing Record 2 of Set 8 | nacozari
# Processing Record 3 of Set 8 | rodbyhavn
# Processing Record 4 of Set 8 | rantepao
# Processing Record 5 of Set 8 | valleyview
# Processing Record 6 of Set 8 | coihaique
# Processing Record 7 of Set 8 | kualakapuas
# Processing Record 8 of Set 8 | patancheru
# Processing Record 9 of Set 8 | ilulissat
# Processing Record 10 of Set 8 | brae
# Processing Record 11 of Set 8 | vila franca do campo
# Processing Record 12 of Set 8 | shenjiamen
# Processing Record 13 of Set 8 | dir
# Processing Record 14 of Set 8 | lashio
# Processing Record 15 of Set 8 | burnie
# Processing Record 16 of Set 8 | turukhansk
# Processing Record 17 of Set 8 | zharkent
# Processing Record 18 of Set 8 | quatre cocos
# Processing Record 19 of Set 8 | kerema
# Processing Record 20 of Set 8 | pavlovskiy
# Processing Record 21 of Set 8 | trairi
# Processing Record 22 of Set 8 | zhanakorgan
# Processing Record 23 of Set 8 | brenham
# Processing Record 24 of Set 8 | phuket
# Processing Record 25 of Set 8 | ossora
# Processing Record 26 of Set 8 | jasper
# Processing Record 27 of Set 8 | kaili
# Processing Record 28 of Set 8 | trenggalek
# Processing Record 29 of Set 8 | thano bula khan
# City not found. Skipping...
# Processing Record 30 of Set 8 | chikhli
# Processing Record 31 of Set 8 | hvide sande
# Processing Record 32 of Set 8 | saurimo
# Processing Record 33 of Set 8 | lunglei
# Processing Record 34 of Set 8 | tecolutla
# Processing Record 35 of Set 8 | toungoo
# City not found. Skipping...
# Processing Record 36 of Set 8 | kruisfontein
# Processing Record 37 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 8 | acapulco
# Processing Record 39 of Set 8 | south venice
# Processing Record 40 of Set 8 | ostersund
# Processing Record 41 of Set 8 | umm lajj
# Processing Record 42 of Set 8 | cidreira
# Processing Record 43 of Set 8 | xai-xai
# Processing Record 44 of Set 8 | pangnirtung
# Processing Record 45 of Set 8 | tahta
# Processing Record 46 of Set 8 | alice town
# Processing Record 47 of Set 8 | bodden town
# Processing Record 48 of Set 8 | nha trang
# Processing Record 49 of Set 8 | manokwari
# Processing Record 50 of Set 8 | dhamnod
# Processing Record 1 of Set 9 | camopi
# Processing Record 2 of Set 9 | burica
# City not found. Skipping...
# Processing Record 3 of Set 9 | formosa
# Processing Record 4 of Set 9 | aklavik
# Processing Record 5 of Set 9 | qaqortoq
# Processing Record 6 of Set 9 | ancud
# Processing Record 7 of Set 9 | porto torres
# Processing Record 8 of Set 9 | sarakhs
# Processing Record 9 of Set 9 | ballina
# Processing Record 10 of Set 9 | bocana de paiwas
# Processing Record 11 of Set 9 | sao joao da barra
# Processing Record 12 of Set 9 | dingle
# Processing Record 13 of Set 9 | preobrazheniye
# Processing Record 14 of Set 9 | tateyama
# Processing Record 15 of Set 9 | san quintin
# Processing Record 16 of Set 9 | albacete
# Processing Record 17 of Set 9 | broome
# Processing Record 18 of Set 9 | tazovskiy
# Processing Record 19 of Set 9 | timbio
# City not found. Skipping...
# Processing Record 20 of Set 9 | marzuq
# Processing Record 21 of Set 9 | port moresby
# Processing Record 22 of Set 9 | batemans bay
# Processing Record 23 of Set 9 | nelson bay
# Processing Record 24 of Set 9 | abu zabad
# Processing Record 25 of Set 9 | mitsamiouli
# Processing Record 26 of Set 9 | airai
# Processing Record 27 of Set 9 | russellville
# Processing Record 28 of Set 9 | inuvik
# Processing Record 29 of Set 9 | surt
# Processing Record 30 of Set 9 | pangody
# Processing Record 31 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 32 of Set 9 | eydhafushi
# Processing Record 33 of Set 9 | fort abbas
# Processing Record 34 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 35 of Set 9 | touros
# Processing Record 36 of Set 9 | severo-kurilsk
# Processing Record 37 of Set 9 | iskateley
# Processing Record 38 of Set 9 | fortuna
# Processing Record 39 of Set 9 | hobyo
# Processing Record 40 of Set 9 | port macquarie
# Processing Record 41 of Set 9 | jonkoping
# Processing Record 42 of Set 9 | port keats
# Processing Record 43 of Set 9 | sembe
# Processing Record 44 of Set 9 | homer
# Processing Record 45 of Set 9 | robertson
# Processing Record 46 of Set 9 | itarema
# Processing Record 47 of Set 9 | broken hill
# Processing Record 48 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 49 of Set 9 | mankachar
# Processing Record 50 of Set 9 | zaysan
# Processing Record 1 of Set 10 | sobolevo
# Processing Record 2 of Set 10 | innisfail
# Processing Record 3 of Set 10 | attingal
# Processing Record 4 of Set 10 | mingaora
# Processing Record 5 of Set 10 | coolum beach
# Processing Record 6 of Set 10 | omaruru
# Processing Record 7 of Set 10 | siniscola
# Processing Record 8 of Set 10 | eenhana
# Processing Record 9 of Set 10 | killam
# Processing Record 10 of Set 10 | constitucion
# Processing Record 11 of Set 10 | ocosingo
# Processing Record 12 of Set 10 | kimbe
# Processing Record 13 of Set 10 | sambava
# Processing Record 14 of Set 10 | katsuura
# Processing Record 15 of Set 10 | puerto madryn
# Processing Record 16 of Set 10 | ormara
# Processing Record 17 of Set 10 | trincomalee
# Processing Record 18 of Set 10 | san patricio
# Processing Record 19 of Set 10 | termiz
# Processing Record 20 of Set 10 | lodja
# Processing Record 21 of Set 10 | tazmalt
# Processing Record 22 of Set 10 | kenai
# Processing Record 23 of Set 10 | mount isa
# Processing Record 24 of Set 10 | reconquista
# Processing Record 25 of Set 10 | port-gentil
# Processing Record 26 of Set 10 | tokur
# Processing Record 27 of Set 10 | zima
# Processing Record 28 of Set 10 | crotone
# Processing Record 29 of Set 10 | saint-donat-de-montcalm
# Processing Record 30 of Set 10 | kahului
# Processing Record 31 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 32 of Set 10 | marburg
# Processing Record 33 of Set 10 | thaton
# Processing Record 34 of Set 10 | lewistown
# Processing Record 35 of Set 10 | sorland
# Processing Record 36 of Set 10 | esmeraldas
# Processing Record 37 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 10 | batagay
# Processing Record 39 of Set 10 | palmer
# Processing Record 40 of Set 10 | bundaberg
# Processing Record 41 of Set 10 | krasnyy chikoy
# Processing Record 42 of Set 10 | flin flon
# Processing Record 43 of Set 10 | dunyapur
# Processing Record 44 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 10 | belmonte
# Processing Record 46 of Set 10 | prince rupert
# Processing Record 47 of Set 10 | sidi ali
# Processing Record 48 of Set 10 | ilmajoki
# Processing Record 49 of Set 10 | hambantota
# Processing Record 50 of Set 10 | klaksvik
# Processing Record 1 of Set 11 | la mata
# Processing Record 2 of Set 11 | umm kaddadah
# Processing Record 3 of Set 11 | bacolod
# Processing Record 4 of Set 11 | dunedin
# Processing Record 5 of Set 11 | paramonga
# Processing Record 6 of Set 11 | komsomolskiy
# Processing Record 7 of Set 11 | buchanan
# Processing Record 8 of Set 11 | santa maria
# Processing Record 9 of Set 11 | paita
# Processing Record 10 of Set 11 | cabedelo
# Processing Record 11 of Set 11 | clovis
# Processing Record 12 of Set 11 | goderich
# Processing Record 13 of Set 11 | sechura
# Processing Record 14 of Set 11 | yekaterinoslavka
# Processing Record 15 of Set 11 | weihai
# Processing Record 16 of Set 11 | mehran
# Processing Record 17 of Set 11 | sorong
# Processing Record 18 of Set 11 | puerto escondido
# Processing Record 19 of Set 11 | inirida
# Processing Record 20 of Set 11 | chumikan
# Processing Record 21 of Set 11 | tabas
# Processing Record 22 of Set 11 | red bluff
# Processing Record 23 of Set 11 | nouadhibou
# Processing Record 24 of Set 11 | kamenka
# Processing Record 25 of Set 11 | necochea
# Processing Record 26 of Set 11 | partenit
# Processing Record 27 of Set 11 | wangdiphodrang
# City not found. Skipping...
# Processing Record 28 of Set 11 | marfino
# Processing Record 29 of Set 11 | evensk
# Processing Record 30 of Set 11 | fort frances
# Processing Record 31 of Set 11 | kavaratti
# Processing Record 32 of Set 11 | tucurui
# Processing Record 33 of Set 11 | sayyan
# Processing Record 34 of Set 11 | verdikoussa
# Processing Record 35 of Set 11 | auburn
# Processing Record 36 of Set 11 | ngawen
# Processing Record 37 of Set 11 | nkhotakota
# Processing Record 38 of Set 11 | arman
# Processing Record 39 of Set 11 | funadhoo
# Processing Record 40 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 41 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 42 of Set 11 | belaya gora
# Processing Record 43 of Set 11 | maceio
# Processing Record 44 of Set 11 | denizli
# Processing Record 45 of Set 11 | aitape
# Processing Record 46 of Set 11 | yerofey pavlovich
# Processing Record 47 of Set 11 | nicoya
# Processing Record 48 of Set 11 | ylojarvi
# Processing Record 49 of Set 11 | baracoa
# Processing Record 50 of Set 11 | itanagar
# Processing Record 1 of Set 12 | atbasar
# Processing Record 2 of Set 12 | koson
# Processing Record 3 of Set 12 | miyako
# Processing Record 4 of Set 12 | yala
# Processing Record 5 of Set 12 | kargil
# Processing Record 6 of Set 12 | folkestone
# Processing Record 7 of Set 12 | mingguang
# Processing Record 8 of Set 12 | rio gallegos
# Processing Record 9 of Set 12 | kalmunai
# Processing Record 10 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 12 | sibut
# Processing Record 12 of Set 12 | roebourne
# Processing Record 13 of Set 12 | durango
# Processing Record 14 of Set 12 | fort smith
# Processing Record 15 of Set 12 | kurilsk
# Processing Record 16 of Set 12 | palauig
# Processing Record 17 of Set 12 | ambon
# Processing Record 18 of Set 12 | dedza
# Processing Record 19 of Set 12 | brahmapuri
# City not found. Skipping...
# Processing Record 20 of Set 12 | knysna
# Processing Record 21 of Set 12 | dolores
# Processing Record 22 of Set 12 | gravdal
# Processing Record 23 of Set 12 | paralimni
# Processing Record 24 of Set 12 | dunkirk
# Processing Record 25 of Set 12 | bida
# Processing Record 26 of Set 12 | nishihara
# Processing Record 27 of Set 12 | ajdabiya
# Processing Record 28 of Set 12 | ust-kut
# Processing Record 29 of Set 12 | laguna de perlas
# Processing Record 30 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 12 | camocim
# Processing Record 32 of Set 12 | ambilobe
# Processing Record 33 of Set 12 | acari
# Processing Record 34 of Set 12 | rocha
# Processing Record 35 of Set 12 | bilibino
# Processing Record 36 of Set 12 | port blair
# Processing Record 37 of Set 12 | kizukuri
# Processing Record 38 of Set 12 | san juan bautista
# Processing Record 39 of Set 12 | guerrero negro
# Processing Record 40 of Set 12 | ibra
# Processing Record 41 of Set 12 | jalingo
# Processing Record 42 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 43 of Set 12 | sao geraldo do araguaia
# Processing Record 44 of Set 12 | ovre ardal
# Processing Record 45 of Set 12 | wanning
# Processing Record 46 of Set 12 | gardez
# Processing Record 47 of Set 12 | dawei
# Processing Record 48 of Set 12 | itoman
# Processing Record 49 of Set 12 | cookshire
# City not found. Skipping...
# Processing Record 50 of Set 12 | camara de lobos
# Processing Record 1 of Set 13 | henties bay
# Processing Record 2 of Set 13 | carauari
# Processing Record 3 of Set 13 | katunino
# Processing Record 4 of Set 13 | graham
# Processing Record 5 of Set 13 | nan
# Processing Record 6 of Set 13 | kuroiso
# Processing Record 7 of Set 13 | kapuskasing
# Processing Record 8 of Set 13 | ammon
# Processing Record 9 of Set 13 | high level
# Processing Record 10 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 12 of Set 13 | yumen
# Processing Record 13 of Set 13 | rexburg
# Processing Record 14 of Set 13 | crown point
# Processing Record 15 of Set 13 | imeni poliny osipenko
# Processing Record 16 of Set 13 | chimbote
# Processing Record 17 of Set 13 | havelock
# Processing Record 18 of Set 13 | kendari
# Processing Record 19 of Set 13 | sola
# Processing Record 20 of Set 13 | tutoia
# Processing Record 21 of Set 13 | amguri
# Processing Record 22 of Set 13 | svetlyy
# Processing Record 23 of Set 13 | acarau
# Processing Record 24 of Set 13 | fereydun kenar
# Processing Record 25 of Set 13 | thunder bay
# Processing Record 26 of Set 13 | ferrol
# Processing Record 27 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 28 of Set 13 | nampula
# Processing Record 29 of Set 13 | sabirabad
# Processing Record 30 of Set 13 | kinablangan
# Processing Record 31 of Set 13 | sangar
# Processing Record 32 of Set 13 | vila
# Processing Record 33 of Set 13 | itaituba
# Processing Record 34 of Set 13 | port hawkesbury
# Processing Record 35 of Set 13 | omboue
# Processing Record 36 of Set 13 | diego de almagro
# Processing Record 37 of Set 13 | helena
# Processing Record 38 of Set 13 | peniche
# Processing Record 39 of Set 13 | hailar
# Processing Record 40 of Set 13 | porkhov
# Processing Record 41 of Set 13 | kpandu
# Processing Record 42 of Set 13 | kokkola
# Processing Record 43 of Set 13 | arenapolis
# Processing Record 44 of Set 13 | sibolga
# Processing Record 45 of Set 13 | marau
# Processing Record 46 of Set 13 | sal rei
# Processing Record 47 of Set 13 | seropedica
# Processing Record 48 of Set 13 | taywarah
# Processing Record 49 of Set 13 | parkes
# Processing Record 50 of Set 13 | clyde river
# Processing Record 1 of Set 14 | port hardy
# Processing Record 2 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 14 | panguipulli
# Processing Record 4 of Set 14 | rafaela
# Processing Record 5 of Set 14 | zhengjiatun
# Processing Record 6 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 14 | sao domingos do maranhao
# Processing Record 8 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 14 | banyo
# Processing Record 10 of Set 14 | ascension
# Processing Record 11 of Set 14 | rock sound
# Processing Record 12 of Set 14 | karaton
# Processing Record 13 of Set 14 | rosetta
# Processing Record 14 of Set 14 | chikwawa
# Processing Record 15 of Set 14 | plettenberg bay
# Processing Record 16 of Set 14 | dalbandin
# Processing Record 17 of Set 14 | seoul
# Processing Record 18 of Set 14 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 19 of Set 14 | marabba
# Processing Record 20 of Set 14 | bilma
# Processing Record 21 of Set 14 | asau
# Processing Record 22 of Set 14 | amahai
# Processing Record 23 of Set 14 | wasilla
# Processing Record 24 of Set 14 | port augusta
# Processing Record 25 of Set 14 | jeannette
# Processing Record 26 of Set 14 | aykhal
# Processing Record 27 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 14 | tam ky
# Processing Record 29 of Set 14 | bitung
# Processing Record 30 of Set 14 | matamba
# Processing Record 31 of Set 14 | kongolo
# Processing Record 32 of Set 14 | naze
# Processing Record 33 of Set 14 | poya
# Processing Record 34 of Set 14 | nago
# Processing Record 35 of Set 14 | avera
# Processing Record 36 of Set 14 | simao
# Processing Record 37 of Set 14 | saint paul
# Processing Record 38 of Set 14 | priiskovyy
# Processing Record 39 of Set 14 | lazaro cardenas
# Processing Record 40 of Set 14 | sulina
# Processing Record 41 of Set 14 | vung tau
# Processing Record 42 of Set 14 | palora
# Processing Record 43 of Set 14 | tucuman
# Processing Record 44 of Set 14 | cutervo
# Processing Record 45 of Set 14 | beloha
# Processing Record 46 of Set 14 | shanghai
# Processing Record 47 of Set 14 | chadan
# Processing Record 48 of Set 14 | bandarbeyla
# Processing Record 49 of Set 14 | yurino
# Processing Record 50 of Set 14 | hofn
# Processing Record 1 of Set 15 | moquegua
# Processing Record 2 of Set 15 | kalashnikovo
# Processing Record 3 of Set 15 | lagos
# Processing Record 4 of Set 15 | estacion coahuila
# Processing Record 5 of Set 15 | novyy urgal
# Processing Record 6 of Set 15 | pyapon
# Processing Record 7 of Set 15 | daru
# Processing Record 8 of Set 15 | ayan
# Processing Record 9 of Set 15 | vestmannaeyjar
# Processing Record 10 of Set 15 | cody
# Processing Record 11 of Set 15 | guymon
# Processing Record 12 of Set 15 | la ronge
# Processing Record 13 of Set 15 | saldanha
# Processing Record 14 of Set 15 | finnsnes
# Processing Record 15 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 15 | xiongyue
# Processing Record 17 of Set 15 | wanaka
# Processing Record 18 of Set 15 | quang ngai
# Processing Record 19 of Set 15 | la peca
# Processing Record 20 of Set 15 | nanticoke
# Processing Record 21 of Set 15 | bendigo
# Processing Record 22 of Set 15 | kawalu
# Processing Record 23 of Set 15 | saryozek
# Processing Record 24 of Set 15 | kitimat
# Processing Record 25 of Set 15 | harpalpur
# Processing Record 26 of Set 15 | ulvik
# Processing Record 27 of Set 15 | pativilca
# Processing Record 28 of Set 15 | odienne
# Processing Record 29 of Set 15 | petropavlovka
# Processing Record 30 of Set 15 | inhambane
# Processing Record 31 of Set 15 | souris
# Processing Record 32 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 33 of Set 15 | yenotayevka
# Processing Record 34 of Set 15 | ulaanbaatar
# Processing Record 35 of Set 15 | andenes
# Processing Record 36 of Set 15 | yendi
# Processing Record 37 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 38 of Set 15 | kununurra
# Processing Record 39 of Set 15 | soyo
# Processing Record 40 of Set 15 | deputatskiy
# Processing Record 41 of Set 15 | tual
# Processing Record 42 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 15 | dubbo
# Processing Record 44 of Set 15 | juanjui
# Processing Record 45 of Set 15 | hervey bay
# Processing Record 46 of Set 15 | boulder city
# Processing Record 47 of Set 15 | blackfoot
# Processing Record 48 of Set 15 | mount gambier
# Processing Record 49 of Set 15 | kalamazoo
# Processing Record 50 of Set 15 | chapais
# Processing Record 1 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 16 | vilkaviskis
# Processing Record 3 of Set 16 | amapa
# Processing Record 4 of Set 16 | mozelos
# Processing Record 5 of Set 16 | alta floresta
# Processing Record 6 of Set 16 | okulovka
# Processing Record 7 of Set 16 | winneba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 694

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df =  pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0         Luderitz -26.6481   15.1594     57.72           clear sky        84
# 1  Arraial Do Cabo -22.9661  -42.0278     69.76     overcast clouds        78
# 2       Winchester  51.0651   -1.3187     53.65           clear sky        80
# 3           Albany  42.6001  -73.9662     62.46           clear sky        60
# 4         Cam Ranh  11.9214  109.1591     80.56    scattered clouds        78
# 5       Georgetown   5.4112  100.3354     80.89        thunderstorm        91
# 6         San Jose  37.3394 -121.8950     82.92          few clouds        53
# 7       Alamogordo  32.8995 -105.9603     80.40           clear sky        28
# 8           Cairns -16.9167  145.7667     69.75          few clouds        83
# 9             Aksu  41.1231   80.2644     66.38     overcast clouds        27
#
#    Cloudiness  Wind Speed Country
# 0           0       16.46      NA
# 1         100        9.22      BR
# 2           0        4.61      GB
# 3           4        1.99      US
# 4          40       10.36      VN
# 5          20        2.30      MY
# 6          20        4.00      US
# 7           0        5.75      US
# 8          14        4.61      AU
# 9         100        4.43      CN

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order_list =[ "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df.reindex(columns=column_order_list)
# Display sample data
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Luderitz      NA -26.6481   15.1594     57.72        84
# 1    Arraial Do Cabo      BR -22.9661  -42.0278     69.76        78
# 2         Winchester      GB  51.0651   -1.3187     53.65        80
# 3             Albany      US  42.6001  -73.9662     62.46        60
# 4           Cam Ranh      VN  11.9214  109.1591     80.56        78
# ..               ...     ...      ...       ...       ...       ...
# 689            Amapa      BR   1.0000  -52.0000     85.57        52
# 690          Mozelos      PT  41.8677   -8.3978     61.88        86
# 691    Alta Floresta      BR  -9.8756  -56.0861     94.82        46
# 692         Okulovka      RU  58.4008   33.2908     45.95        97
# 693          Winneba      GH   5.3511   -0.6231     75.92        86
#
#      Cloudiness  Wind Speed Current Description
# 0             0       16.46           clear sky
# 1           100        9.22     overcast clouds
# 2             0        4.61           clear sky
# 3             4        1.99           clear sky
# 4            40       10.36    scattered clouds
# ..          ...         ...                 ...
# 689          99        5.75     overcast clouds
# 690           2        4.61           clear sky
# 691          40        5.75    scattered clouds
# 692         100        6.89     overcast clouds
# 693          42        6.38    scattered clouds
#
# [694 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
city_weather_csv = "WeatherPy_database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(city_weather_csv, index_label="City_ID")
