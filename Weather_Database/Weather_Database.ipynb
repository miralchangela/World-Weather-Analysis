# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 718

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description =city_weather["weather"][0]["description"] 
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                           "Country": city_country
                         })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 3 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 1 | kesennuma
# City not found. Skipping...
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | northam
# Processing Record 10 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 1 | mahebourg
# Processing Record 12 of Set 1 | luderitz
# Processing Record 13 of Set 1 | dikson
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | tieling
# Processing Record 21 of Set 1 | itupiranga
# Processing Record 22 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 1 | mareeba
# Processing Record 24 of Set 1 | cidreira
# Processing Record 25 of Set 1 | manokwari
# Processing Record 26 of Set 1 | thompson
# Processing Record 27 of Set 1 | tiksi
# Processing Record 28 of Set 1 | new norfolk
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | rawson
# Processing Record 31 of Set 1 | saint george
# Processing Record 32 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | sisophon
# Processing Record 35 of Set 1 | te anau
# Processing Record 36 of Set 1 | mar del plata
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | bati
# Processing Record 40 of Set 1 | lima
# Processing Record 41 of Set 1 | bambous virieux
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | srednekolymsk
# Processing Record 44 of Set 1 | chifeng
# Processing Record 45 of Set 1 | birjand
# Processing Record 46 of Set 1 | hagere hiywet
# Processing Record 47 of Set 1 | baruun-urt
# Processing Record 48 of Set 1 | hilo
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | butaritari
# Processing Record 3 of Set 2 | vallenar
# Processing Record 4 of Set 2 | mahibadhoo
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | avarua
# Processing Record 9 of Set 2 | saskylakh
# Processing Record 10 of Set 2 | lahaina
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | khatanga
# Processing Record 14 of Set 2 | dunedin
# Processing Record 15 of Set 2 | kruisfontein
# Processing Record 16 of Set 2 | san cristobal
# Processing Record 17 of Set 2 | victoria
# Processing Record 18 of Set 2 | tuatapere
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | amapa
# Processing Record 21 of Set 2 | san patricio
# Processing Record 22 of Set 2 | hovd
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | kumhari
# Processing Record 26 of Set 2 | balkanabat
# Processing Record 27 of Set 2 | poum
# Processing Record 28 of Set 2 | meulaboh
# Processing Record 29 of Set 2 | richards bay
# Processing Record 30 of Set 2 | ohara
# Processing Record 31 of Set 2 | provideniya
# Processing Record 32 of Set 2 | nisia floresta
# Processing Record 33 of Set 2 | fortuna
# Processing Record 34 of Set 2 | beloha
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | presidencia roque saenz pena
# Processing Record 37 of Set 2 | paraiso
# Processing Record 38 of Set 2 | deputatskiy
# Processing Record 39 of Set 2 | acuna
# City not found. Skipping...
# Processing Record 40 of Set 2 | andselv
# City not found. Skipping...
# Processing Record 41 of Set 2 | beisfjord
# Processing Record 42 of Set 2 | verkhniy baskunchak
# Processing Record 43 of Set 2 | tasiilaq
# Processing Record 44 of Set 2 | avera
# Processing Record 45 of Set 2 | esperance
# Processing Record 46 of Set 2 | peniche
# Processing Record 47 of Set 2 | gravdal
# Processing Record 48 of Set 2 | gimbi
# Processing Record 49 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 2 | quatre cocos
# Processing Record 1 of Set 3 | bathsheba
# Processing Record 2 of Set 3 | japura
# Processing Record 3 of Set 3 | yantal
# Processing Record 4 of Set 3 | puerto ayora
# Processing Record 5 of Set 3 | saint-ambroise
# Processing Record 6 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 3 | zhangjiakou
# Processing Record 8 of Set 3 | sola
# Processing Record 9 of Set 3 | innisfail
# Processing Record 10 of Set 3 | novikovo
# Processing Record 11 of Set 3 | yar-sale
# Processing Record 12 of Set 3 | upernavik
# Processing Record 13 of Set 3 | kaitangata
# Processing Record 14 of Set 3 | genhe
# Processing Record 15 of Set 3 | aklavik
# Processing Record 16 of Set 3 | hervey bay
# Processing Record 17 of Set 3 | aljezur
# Processing Record 18 of Set 3 | esso
# Processing Record 19 of Set 3 | alta floresta
# Processing Record 20 of Set 3 | gladstone
# Processing Record 21 of Set 3 | tuktoyaktuk
# Processing Record 22 of Set 3 | teya
# Processing Record 23 of Set 3 | schmolln
# Processing Record 24 of Set 3 | corinto
# Processing Record 25 of Set 3 | antofagasta
# Processing Record 26 of Set 3 | lorengau
# Processing Record 27 of Set 3 | villa bruzual
# Processing Record 28 of Set 3 | mandalgovi
# Processing Record 29 of Set 3 | sankt andra
# City not found. Skipping...
# Processing Record 30 of Set 3 | ahipara
# Processing Record 31 of Set 3 | constitucion
# Processing Record 32 of Set 3 | baneh
# Processing Record 33 of Set 3 | bluff
# Processing Record 34 of Set 3 | mpika
# Processing Record 35 of Set 3 | linhares
# Processing Record 36 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 3 | sao filipe
# Processing Record 38 of Set 3 | kavieng
# Processing Record 39 of Set 3 | port alfred
# Processing Record 40 of Set 3 | camana
# Processing Record 41 of Set 3 | takoradi
# Processing Record 42 of Set 3 | cockburn town
# Processing Record 43 of Set 3 | kollam
# Processing Record 44 of Set 3 | akureyri
# Processing Record 45 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 46 of Set 3 | carnarvon
# Processing Record 47 of Set 3 | shingu
# Processing Record 48 of Set 3 | ciudad bolivar
# Processing Record 49 of Set 3 | malvern
# Processing Record 50 of Set 3 | longyearbyen
# Processing Record 1 of Set 4 | araria
# Processing Record 2 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 3 of Set 4 | half moon bay
# Processing Record 4 of Set 4 | puerto escondido
# Processing Record 5 of Set 4 | calituban
# Processing Record 6 of Set 4 | bridgetown
# Processing Record 7 of Set 4 | katsuura
# Processing Record 8 of Set 4 | kahului
# Processing Record 9 of Set 4 | zhanaozen
# Processing Record 10 of Set 4 | murgab
# Processing Record 11 of Set 4 | ostrovnoy
# Processing Record 12 of Set 4 | delta del tigre
# Processing Record 13 of Set 4 | sur
# Processing Record 14 of Set 4 | barao de melgaco
# Processing Record 15 of Set 4 | spring valley
# Processing Record 16 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 4 | nemuro
# Processing Record 18 of Set 4 | marathon
# Processing Record 19 of Set 4 | gat
# Processing Record 20 of Set 4 | sitka
# Processing Record 21 of Set 4 | chuy
# Processing Record 22 of Set 4 | nikolskoye
# Processing Record 23 of Set 4 | hasaki
# Processing Record 24 of Set 4 | cassilandia
# Processing Record 25 of Set 4 | rundu
# Processing Record 26 of Set 4 | ahuimanu
# Processing Record 27 of Set 4 | taga
# Processing Record 28 of Set 4 | nome
# Processing Record 29 of Set 4 | keuruu
# Processing Record 30 of Set 4 | biograd na moru
# Processing Record 31 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 4 | abha
# Processing Record 33 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 4 | karratha
# Processing Record 35 of Set 4 | kapuskasing
# Processing Record 36 of Set 4 | savannah bight
# Processing Record 37 of Set 4 | malanje
# Processing Record 38 of Set 4 | mizpe ramon
# City not found. Skipping...
# Processing Record 39 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 4 | vila franca do campo
# Processing Record 41 of Set 4 | clyde river
# Processing Record 42 of Set 4 | torbay
# Processing Record 43 of Set 4 | lamu
# Processing Record 44 of Set 4 | custodia
# Processing Record 45 of Set 4 | bengkulu
# Processing Record 46 of Set 4 | tura
# Processing Record 47 of Set 4 | yulara
# Processing Record 48 of Set 4 | burnie
# Processing Record 49 of Set 4 | ponta do sol
# Processing Record 50 of Set 4 | saldanha
# Processing Record 1 of Set 5 | margate
# Processing Record 2 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 5 | ossora
# Processing Record 4 of Set 5 | erenhot
# Processing Record 5 of Set 5 | pankrushikha
# Processing Record 6 of Set 5 | airai
# Processing Record 7 of Set 5 | reforma
# Processing Record 8 of Set 5 | los chiles
# Processing Record 9 of Set 5 | kudahuvadhoo
# Processing Record 10 of Set 5 | eucaliptus
# Processing Record 11 of Set 5 | valley
# Processing Record 12 of Set 5 | fiditi
# Processing Record 13 of Set 5 | alofi
# Processing Record 14 of Set 5 | gasa
# Processing Record 15 of Set 5 | dalvik
# Processing Record 16 of Set 5 | kulhudhuffushi
# Processing Record 17 of Set 5 | zhangye
# Processing Record 18 of Set 5 | sibolga
# Processing Record 19 of Set 5 | geraldton
# Processing Record 20 of Set 5 | kodiak
# Processing Record 21 of Set 5 | port hedland
# Processing Record 22 of Set 5 | bredasdorp
# Processing Record 23 of Set 5 | trincomalee
# Processing Record 24 of Set 5 | kumano
# Processing Record 25 of Set 5 | kirakira
# Processing Record 26 of Set 5 | eyl
# Processing Record 27 of Set 5 | broken hill
# Processing Record 28 of Set 5 | lompoc
# Processing Record 29 of Set 5 | edd
# Processing Record 30 of Set 5 | souillac
# Processing Record 31 of Set 5 | sayyan
# Processing Record 32 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 5 | blagoyevo
# Processing Record 34 of Set 5 | katherine
# Processing Record 35 of Set 5 | yurino
# Processing Record 36 of Set 5 | lishui
# Processing Record 37 of Set 5 | jawhar
# Processing Record 38 of Set 5 | tiarei
# Processing Record 39 of Set 5 | pemberton
# Processing Record 40 of Set 5 | marsh harbour
# Processing Record 41 of Set 5 | cabo san lucas
# Processing Record 42 of Set 5 | gamba
# Processing Record 43 of Set 5 | nevsehir
# Processing Record 44 of Set 5 | tual
# Processing Record 45 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 5 | arraial do cabo
# Processing Record 47 of Set 5 | nalut
# Processing Record 48 of Set 5 | arusha
# Processing Record 49 of Set 5 | bud
# Processing Record 50 of Set 5 | devonport
# Processing Record 1 of Set 6 | omboue
# Processing Record 2 of Set 6 | iralaya
# Processing Record 3 of Set 6 | labuhan
# Processing Record 4 of Set 6 | touros
# Processing Record 5 of Set 6 | mayo
# Processing Record 6 of Set 6 | qaqortoq
# Processing Record 7 of Set 6 | kaniama
# Processing Record 8 of Set 6 | ono
# Processing Record 9 of Set 6 | mitsamiouli
# Processing Record 10 of Set 6 | bida
# Processing Record 11 of Set 6 | charleston
# Processing Record 12 of Set 6 | tirumullaivasal
# Processing Record 13 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 6 | mount gambier
# Processing Record 15 of Set 6 | palm coast
# Processing Record 16 of Set 6 | axim
# Processing Record 17 of Set 6 | ca mau
# Processing Record 18 of Set 6 | kuhdasht
# Processing Record 19 of Set 6 | yekaterinoslavka
# Processing Record 20 of Set 6 | carutapera
# Processing Record 21 of Set 6 | caala
# Processing Record 22 of Set 6 | ayagoz
# Processing Record 23 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 24 of Set 6 | kanigoro
# Processing Record 25 of Set 6 | viedma
# Processing Record 26 of Set 6 | harrisburg
# Processing Record 27 of Set 6 | dingle
# Processing Record 28 of Set 6 | svetlaya
# Processing Record 29 of Set 6 | hithadhoo
# Processing Record 30 of Set 6 | horta
# Processing Record 31 of Set 6 | sorland
# Processing Record 32 of Set 6 | iqaluit
# Processing Record 33 of Set 6 | mundwa
# Processing Record 34 of Set 6 | salalah
# Processing Record 35 of Set 6 | namibe
# Processing Record 36 of Set 6 | sioux lookout
# Processing Record 37 of Set 6 | zyryanka
# Processing Record 38 of Set 6 | bastia
# Processing Record 39 of Set 6 | galveston
# Processing Record 40 of Set 6 | mendoza
# Processing Record 41 of Set 6 | nuuk
# Processing Record 42 of Set 6 | tigil
# Processing Record 43 of Set 6 | kontagora
# Processing Record 44 of Set 6 | mao
# Processing Record 45 of Set 6 | marzuq
# Processing Record 46 of Set 6 | vardo
# Processing Record 47 of Set 6 | severo-kurilsk
# Processing Record 48 of Set 6 | colares
# Processing Record 49 of Set 6 | papasquiaro
# City not found. Skipping...
# Processing Record 50 of Set 6 | pevek
# Processing Record 1 of Set 7 | camacha
# Processing Record 2 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 7 | olafsvik
# Processing Record 4 of Set 7 | mamallapuram
# Processing Record 5 of Set 7 | banda aceh
# Processing Record 6 of Set 7 | paamiut
# Processing Record 7 of Set 7 | chengde
# Processing Record 8 of Set 7 | tukrah
# Processing Record 9 of Set 7 | faya
# Processing Record 10 of Set 7 | poya
# Processing Record 11 of Set 7 | baykit
# Processing Record 12 of Set 7 | cabedelo
# Processing Record 13 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 14 of Set 7 | sawakin
# Processing Record 15 of Set 7 | hami
# Processing Record 16 of Set 7 | batagay-alyta
# Processing Record 17 of Set 7 | kerman
# Processing Record 18 of Set 7 | aswan
# Processing Record 19 of Set 7 | tomatlan
# Processing Record 20 of Set 7 | nanortalik
# Processing Record 21 of Set 7 | yangambi
# Processing Record 22 of Set 7 | bestobe
# Processing Record 23 of Set 7 | ulladulla
# Processing Record 24 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 25 of Set 7 | naze
# Processing Record 26 of Set 7 | kristianstad
# Processing Record 27 of Set 7 | amahai
# Processing Record 28 of Set 7 | pisco
# Processing Record 29 of Set 7 | talnakh
# Processing Record 30 of Set 7 | obilnoye
# Processing Record 31 of Set 7 | marawi
# Processing Record 32 of Set 7 | codrington
# Processing Record 33 of Set 7 | lata
# Processing Record 34 of Set 7 | ibra
# Processing Record 35 of Set 7 | berlevag
# Processing Record 36 of Set 7 | norway
# Processing Record 37 of Set 7 | tezu
# Processing Record 38 of Set 7 | divnomorskoye
# Processing Record 39 of Set 7 | salvador
# Processing Record 40 of Set 7 | milkovo
# Processing Record 41 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 7 | los llanos de aridane
# Processing Record 43 of Set 7 | kishtwar
# Processing Record 44 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 7 | colmenar viejo
# Processing Record 46 of Set 7 | morondava
# Processing Record 47 of Set 7 | pangnirtung
# Processing Record 48 of Set 7 | klaksvik
# Processing Record 49 of Set 7 | wagar
# Processing Record 50 of Set 7 | cervo
# Processing Record 1 of Set 8 | isangel
# Processing Record 2 of Set 8 | taltal
# Processing Record 3 of Set 8 | broome
# Processing Record 4 of Set 8 | diego de almagro
# Processing Record 5 of Set 8 | fairbanks
# Processing Record 6 of Set 8 | verkhoyansk
# Processing Record 7 of Set 8 | la ronge
# Processing Record 8 of Set 8 | ilulissat
# Processing Record 9 of Set 8 | hamilton
# Processing Record 10 of Set 8 | padang
# Processing Record 11 of Set 8 | molochnoye
# Processing Record 12 of Set 8 | allapalli
# Processing Record 13 of Set 8 | kavaratti
# Processing Record 14 of Set 8 | havelock
# Processing Record 15 of Set 8 | la paz
# Processing Record 16 of Set 8 | agadez
# Processing Record 17 of Set 8 | roald
# Processing Record 18 of Set 8 | mosquera
# Processing Record 19 of Set 8 | borama
# City not found. Skipping...
# Processing Record 20 of Set 8 | red bluff
# Processing Record 21 of Set 8 | bethel
# Processing Record 22 of Set 8 | wajima
# Processing Record 23 of Set 8 | vinh
# Processing Record 24 of Set 8 | lavrentiya
# Processing Record 25 of Set 8 | kigoma
# Processing Record 26 of Set 8 | narsaq
# Processing Record 27 of Set 8 | ust-uda
# Processing Record 28 of Set 8 | wolmaranstad
# City not found. Skipping...
# Processing Record 29 of Set 8 | paso de carrasco
# Processing Record 30 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 8 | guerrero negro
# Processing Record 32 of Set 8 | raglan
# Processing Record 33 of Set 8 | novopavlovka
# Processing Record 34 of Set 8 | vetlanda
# Processing Record 35 of Set 8 | inta
# Processing Record 36 of Set 8 | vrcin
# Processing Record 37 of Set 8 | vangaindrano
# Processing Record 38 of Set 8 | hambantota
# Processing Record 39 of Set 8 | butembo
# Processing Record 40 of Set 8 | anadyr
# Processing Record 41 of Set 8 | sao joao da barra
# Processing Record 42 of Set 8 | the valley
# Processing Record 43 of Set 8 | brainerd
# Processing Record 44 of Set 8 | hvammstangi
# City not found. Skipping...
# Processing Record 45 of Set 8 | komsomolskiy
# Processing Record 46 of Set 8 | nishihara
# Processing Record 47 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 48 of Set 8 | bay city
# Processing Record 49 of Set 8 | boca do acre
# Processing Record 50 of Set 8 | cazaje
# City not found. Skipping...
# Processing Record 1 of Set 9 | mehamn
# Processing Record 2 of Set 9 | isiro
# Processing Record 3 of Set 9 | middelburg
# Processing Record 4 of Set 9 | cordoba
# Processing Record 5 of Set 9 | leningradskiy
# Processing Record 6 of Set 9 | bangassou
# Processing Record 7 of Set 9 | encruzilhada do sul
# Processing Record 8 of Set 9 | alenquer
# Processing Record 9 of Set 9 | soe
# Processing Record 10 of Set 9 | andenes
# Processing Record 11 of Set 9 | tondano
# Processing Record 12 of Set 9 | pemba
# Processing Record 13 of Set 9 | east stroudsburg
# Processing Record 14 of Set 9 | poptun
# Processing Record 15 of Set 9 | coos bay
# Processing Record 16 of Set 9 | ponnani
# Processing Record 17 of Set 9 | kamenka
# Processing Record 18 of Set 9 | waipawa
# Processing Record 19 of Set 9 | banfora
# Processing Record 20 of Set 9 | kalmunai
# Processing Record 21 of Set 9 | armacao dos buzios
# City not found. Skipping...
# Processing Record 22 of Set 9 | chiniot
# Processing Record 23 of Set 9 | saint anthony
# Processing Record 24 of Set 9 | batsfjord
# Processing Record 25 of Set 9 | honningsvag
# Processing Record 26 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 27 of Set 9 | luwuk
# Processing Record 28 of Set 9 | acapulco
# Processing Record 29 of Set 9 | tacuarembo
# Processing Record 30 of Set 9 | puerto madryn
# Processing Record 31 of Set 9 | skegness
# Processing Record 32 of Set 9 | westport
# Processing Record 33 of Set 9 | uwayl
# City not found. Skipping...
# Processing Record 34 of Set 9 | bagdarin
# Processing Record 35 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 9 | arman
# Processing Record 37 of Set 9 | zhezkazgan
# Processing Record 38 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 39 of Set 9 | ankpa
# Processing Record 40 of Set 9 | bethanien
# Processing Record 41 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 42 of Set 9 | ibotirama
# Processing Record 43 of Set 9 | port hardy
# Processing Record 44 of Set 9 | manta
# Processing Record 45 of Set 9 | ancud
# Processing Record 46 of Set 9 | savinka
# Processing Record 47 of Set 9 | jumla
# Processing Record 48 of Set 9 | njombe
# Processing Record 49 of Set 9 | sapanta
# Processing Record 50 of Set 9 | balykshi
# Processing Record 1 of Set 10 | taoudenni
# Processing Record 2 of Set 10 | nouadhibou
# Processing Record 3 of Set 10 | santa isabel do rio negro
# Processing Record 4 of Set 10 | conway
# Processing Record 5 of Set 10 | biak
# Processing Record 6 of Set 10 | aykhal
# Processing Record 7 of Set 10 | hirara
# Processing Record 8 of Set 10 | deep river
# Processing Record 9 of Set 10 | vila velha
# Processing Record 10 of Set 10 | anamur
# Processing Record 11 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 10 | mahajanga
# Processing Record 13 of Set 10 | atasu
# Processing Record 14 of Set 10 | kysyl-syr
# Processing Record 15 of Set 10 | uvinza
# Processing Record 16 of Set 10 | russell
# Processing Record 17 of Set 10 | pokrovsk
# Processing Record 18 of Set 10 | rosario
# Processing Record 19 of Set 10 | slyudyanka
# Processing Record 20 of Set 10 | ugoofaaru
# Processing Record 21 of Set 10 | alyangula
# Processing Record 22 of Set 10 | mastic beach
# Processing Record 23 of Set 10 | altamira
# Processing Record 24 of Set 10 | christchurch
# Processing Record 25 of Set 10 | myitkyina
# Processing Record 26 of Set 10 | sayan
# Processing Record 27 of Set 10 | hornepayne
# Processing Record 28 of Set 10 | yining
# Processing Record 29 of Set 10 | iquitos
# Processing Record 30 of Set 10 | norman wells
# Processing Record 31 of Set 10 | naryan-mar
# Processing Record 32 of Set 10 | zolotinka
# City not found. Skipping...
# Processing Record 33 of Set 10 | burica
# City not found. Skipping...
# Processing Record 34 of Set 10 | karatau
# Processing Record 35 of Set 10 | tautira
# Processing Record 36 of Set 10 | tucuman
# Processing Record 37 of Set 10 | boke
# Processing Record 38 of Set 10 | albina
# Processing Record 39 of Set 10 | katangli
# Processing Record 40 of Set 10 | camargo
# Processing Record 41 of Set 10 | rzhev
# Processing Record 42 of Set 10 | minab
# Processing Record 43 of Set 10 | chauk
# Processing Record 44 of Set 10 | severodvinsk
# Processing Record 45 of Set 10 | shenkursk
# Processing Record 46 of Set 10 | talara
# Processing Record 47 of Set 10 | pochutla
# Processing Record 48 of Set 10 | beringovskiy
# Processing Record 49 of Set 10 | nioro
# Processing Record 50 of Set 10 | tutoia
# Processing Record 1 of Set 11 | jingdezhen
# Processing Record 2 of Set 11 | pyapon
# Processing Record 3 of Set 11 | asau
# Processing Record 4 of Set 11 | taft
# Processing Record 5 of Set 11 | ulety
# Processing Record 6 of Set 11 | bull savanna
# Processing Record 7 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 11 | ishigaki
# Processing Record 9 of Set 11 | manggar
# Processing Record 10 of Set 11 | sungaipenuh
# Processing Record 11 of Set 11 | san rafael
# Processing Record 12 of Set 11 | fernie
# Processing Record 13 of Set 11 | pithoro
# Processing Record 14 of Set 11 | goderich
# Processing Record 15 of Set 11 | colac
# Processing Record 16 of Set 11 | nizwa
# Processing Record 17 of Set 11 | faanui
# Processing Record 18 of Set 11 | college
# Processing Record 19 of Set 11 | lac du bonnet
# Processing Record 20 of Set 11 | lares
# Processing Record 21 of Set 11 | saint-pierre
# Processing Record 22 of Set 11 | bandar-e lengeh
# Processing Record 23 of Set 11 | pangai
# Processing Record 24 of Set 11 | bereda
# Processing Record 25 of Set 11 | ustka
# Processing Record 26 of Set 11 | kutum
# Processing Record 27 of Set 11 | kropotkin
# Processing Record 28 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 11 | alice springs
# Processing Record 30 of Set 11 | batemans bay
# Processing Record 31 of Set 11 | san joaquin
# Processing Record 32 of Set 11 | boende
# Processing Record 33 of Set 11 | bonnyville
# Processing Record 34 of Set 11 | fort nelson
# Processing Record 35 of Set 11 | umm lajj
# Processing Record 36 of Set 11 | wanning
# Processing Record 37 of Set 11 | yerbogachen
# Processing Record 38 of Set 11 | blackfoot
# Processing Record 39 of Set 11 | kalabo
# Processing Record 40 of Set 11 | nuevo progreso
# Processing Record 41 of Set 11 | gambela
# Processing Record 42 of Set 11 | jiazi
# Processing Record 43 of Set 11 | sobolevo
# Processing Record 44 of Set 11 | oranjemund
# Processing Record 45 of Set 11 | pangkalanbuun
# Processing Record 46 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 11 | high level
# Processing Record 48 of Set 11 | ocampo
# Processing Record 49 of Set 11 | vao
# Processing Record 50 of Set 11 | alexandria
# Processing Record 1 of Set 12 | adrar
# Processing Record 2 of Set 12 | kandrian
# Processing Record 3 of Set 12 | panaba
# Processing Record 4 of Set 12 | ambilobe
# Processing Record 5 of Set 12 | iquique
# Processing Record 6 of Set 12 | rabak
# Processing Record 7 of Set 12 | xining
# Processing Record 8 of Set 12 | samana
# Processing Record 9 of Set 12 | langres
# Processing Record 10 of Set 12 | tromso
# Processing Record 11 of Set 12 | masty
# Processing Record 12 of Set 12 | huarmey
# Processing Record 13 of Set 12 | bansda
# City not found. Skipping...
# Processing Record 14 of Set 12 | nizhneangarsk
# Processing Record 15 of Set 12 | bonavista
# Processing Record 16 of Set 12 | kosh-agach
# Processing Record 17 of Set 12 | chumikan
# Processing Record 18 of Set 12 | rincon
# Processing Record 19 of Set 12 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 12 | bakchar
# Processing Record 21 of Set 12 | port lincoln
# Processing Record 22 of Set 12 | waddan
# Processing Record 23 of Set 12 | araouane
# Processing Record 24 of Set 12 | merauke
# Processing Record 25 of Set 12 | ivybridge
# Processing Record 26 of Set 12 | calvinia
# Processing Record 27 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 28 of Set 12 | pedasi
# Processing Record 29 of Set 12 | porto santo
# Processing Record 30 of Set 12 | yerkoy
# Processing Record 31 of Set 12 | hudson bay
# Processing Record 32 of Set 12 | francavilla al mare
# Processing Record 33 of Set 12 | mahaicony
# City not found. Skipping...
# Processing Record 34 of Set 12 | damara
# Processing Record 35 of Set 12 | pendleton
# Processing Record 36 of Set 12 | tingo maria
# Processing Record 37 of Set 12 | santana
# Processing Record 38 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 39 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 40 of Set 12 | mikhaylovka
# Processing Record 41 of Set 12 | kilmez
# City not found. Skipping...
# Processing Record 42 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 43 of Set 12 | khani
# Processing Record 44 of Set 12 | havre-saint-pierre
# Processing Record 45 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 46 of Set 12 | bubaque
# Processing Record 47 of Set 12 | kalispell
# Processing Record 48 of Set 12 | loa janan
# Processing Record 49 of Set 12 | dahuk
# Processing Record 50 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 1 of Set 13 | luoyang
# Processing Record 2 of Set 13 | never
# Processing Record 3 of Set 13 | wageningen
# Processing Record 4 of Set 13 | maceio
# Processing Record 5 of Set 13 | sonqor
# Processing Record 6 of Set 13 | nacala
# Processing Record 7 of Set 13 | kashmor
# Processing Record 8 of Set 13 | jiuquan
# Processing Record 9 of Set 13 | itaituba
# Processing Record 10 of Set 13 | laranjeiras do sul
# Processing Record 11 of Set 13 | tawau
# Processing Record 12 of Set 13 | port-gentil
# Processing Record 13 of Set 13 | sao gabriel da cachoeira
# Processing Record 14 of Set 13 | kirishi
# Processing Record 15 of Set 13 | pucallpa
# Processing Record 16 of Set 13 | san quintin
# Processing Record 17 of Set 13 | port macquarie
# Processing Record 18 of Set 13 | rio grande
# Processing Record 19 of Set 13 | tillabery
# City not found. Skipping...
# Processing Record 20 of Set 13 | am timan
# Processing Record 21 of Set 13 | valday
# Processing Record 22 of Set 13 | birao
# Processing Record 23 of Set 13 | coahuayana
# Processing Record 24 of Set 13 | roebourne
# Processing Record 25 of Set 13 | phanat nikhom
# Processing Record 26 of Set 13 | ust-kuyga
# Processing Record 27 of Set 13 | zverinogolovskoye
# Processing Record 28 of Set 13 | ouesso
# Processing Record 29 of Set 13 | xai-xai
# Processing Record 30 of Set 13 | zirandaro
# Processing Record 31 of Set 13 | buala
# Processing Record 32 of Set 13 | abu jubayhah
# City not found. Skipping...
# Processing Record 33 of Set 13 | jizan
# Processing Record 34 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 35 of Set 13 | rock sound
# Processing Record 36 of Set 13 | hounde
# Processing Record 37 of Set 13 | coari
# Processing Record 38 of Set 13 | kununurra
# Processing Record 39 of Set 13 | tarata
# Processing Record 40 of Set 13 | hofn
# Processing Record 41 of Set 13 | villanueva de cordoba
# Processing Record 42 of Set 13 | rio claro
# Processing Record 43 of Set 13 | okhotsk
# Processing Record 44 of Set 13 | nanchang
# Processing Record 45 of Set 13 | grand gaube
# Processing Record 46 of Set 13 | khandbari
# Processing Record 47 of Set 13 | xinqing
# Processing Record 48 of Set 13 | orotukan
# Processing Record 49 of Set 13 | marienburg
# Processing Record 50 of Set 13 | acajutla
# Processing Record 1 of Set 14 | frontignan
# Processing Record 2 of Set 14 | iza
# Processing Record 3 of Set 14 | garden city
# Processing Record 4 of Set 14 | tazovskiy
# Processing Record 5 of Set 14 | ushtobe
# Processing Record 6 of Set 14 | pitimbu
# Processing Record 7 of Set 14 | ballesteros
# Processing Record 8 of Set 14 | powassan
# Processing Record 9 of Set 14 | riyadh
# Processing Record 10 of Set 14 | grafton
# Processing Record 11 of Set 14 | jinji
# Processing Record 12 of Set 14 | arlit
# Processing Record 13 of Set 14 | acarau
# Processing Record 14 of Set 14 | aitape
# Processing Record 15 of Set 14 | soyo
# Processing Record 16 of Set 14 | rabo de peixe
# Processing Record 17 of Set 14 | marquette
# Processing Record 18 of Set 14 | ankang
# Processing Record 19 of Set 14 | prince rupert
# Processing Record 20 of Set 14 | bachaquero
# Processing Record 21 of Set 14 | arkhangelsk
# Processing Record 22 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 23 of Set 14 | maltahohe
# Processing Record 24 of Set 14 | envira
# Processing Record 25 of Set 14 | nyurba
# Processing Record 26 of Set 14 | novo aripuana
# Processing Record 27 of Set 14 | voznesenye
# Processing Record 28 of Set 14 | ardakan
# Processing Record 29 of Set 14 | pacific grove
# Processing Record 30 of Set 14 | mezen
# Processing Record 31 of Set 14 | neuquen
# Processing Record 32 of Set 14 | kabac
# Processing Record 33 of Set 14 | arys
# Processing Record 34 of Set 14 | progreso
# Processing Record 35 of Set 14 | eyrarbakki
# Processing Record 36 of Set 14 | kharp
# Processing Record 37 of Set 14 | fare
# Processing Record 38 of Set 14 | ust-tsilma
# Processing Record 39 of Set 14 | meadow lake
# Processing Record 40 of Set 14 | along
# Processing Record 41 of Set 14 | bolotnoye
# Processing Record 42 of Set 14 | mangrol
# Processing Record 43 of Set 14 | funadhoo
# Processing Record 44 of Set 14 | kyra
# Processing Record 45 of Set 14 | hun
# Processing Record 46 of Set 14 | vanavara
# Processing Record 47 of Set 14 | lichuan
# Processing Record 48 of Set 14 | tuy hoa
# Processing Record 49 of Set 14 | carlos antonio lopez
# Processing Record 50 of Set 14 | huancavelica
# Processing Record 1 of Set 15 | tehachapi
# Processing Record 2 of Set 15 | bardiyah
# Processing Record 3 of Set 15 | martapura
# Processing Record 4 of Set 15 | saint-augustin
# Processing Record 5 of Set 15 | belmonte
# Processing Record 6 of Set 15 | skjervoy
# Processing Record 7 of Set 15 | madinat sittah uktubar
# Processing Record 8 of Set 15 | antalaha
# Processing Record 9 of Set 15 | conde
# Processing Record 10 of Set 15 | suntar
# Processing Record 11 of Set 15 | mehran
# Processing Record 12 of Set 15 | ceuta
# Processing Record 13 of Set 15 | whitehorse
# Processing Record 14 of Set 15 | tatawin
# Processing Record 15 of Set 15 | coihaique
# Processing Record 16 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 15 | troitsko-pechorsk
# Processing Record 18 of Set 15 | coffs harbour
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 653

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df =  pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0   East London -33.0153   27.9116     66.54    scattered clouds        80
# 1       Qaanaaq  77.4840  -69.3632     13.23          few clouds        69
# 2          Lebu -37.6167  -73.6500     51.57     overcast clouds        94
# 3         Kapaa  22.0752 -159.3190     84.52          few clouds        73
# 4       Northam  51.0333   -4.2167     59.25     overcast clouds        82
# 5     Mahebourg -20.4081   57.7000     70.09    scattered clouds        68
# 6      Luderitz -26.6481   15.1594     56.14           clear sky        65
# 7        Dikson  73.5069   80.5464     34.84     overcast clouds        83
# 8      Cherskiy  68.7500  161.3000     33.80     overcast clouds        61
# 9  Punta Arenas -53.1500  -70.9167     46.51    scattered clouds        57
#
#    Cloudiness  Wind Speed Country
# 0          39       18.32      ZA
# 1          15        6.33      GL
# 2         100       14.34      CL
# 3          20       10.36      US
# 4          91       21.41      GB
# 5          40        8.05      MU
# 6           6       14.90      NA
# 7         100       17.18      RU
# 8         100        2.80      RU
# 9          40       35.68      CL

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order_list =[ "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df.reindex(columns=column_order_list)
# Display sample data
city_data_df[0:10]
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   East London      ZA -33.0153   27.9116     66.54        80          39
# 1       Qaanaaq      GL  77.4840  -69.3632     13.23        69          15
# 2          Lebu      CL -37.6167  -73.6500     51.57        94         100
# 3         Kapaa      US  22.0752 -159.3190     84.52        73          20
# 4       Northam      GB  51.0333   -4.2167     59.25        82          91
# 5     Mahebourg      MU -20.4081   57.7000     70.09        68          40
# 6      Luderitz      NA -26.6481   15.1594     56.14        65           6
# 7        Dikson      RU  73.5069   80.5464     34.84        83         100
# 8      Cherskiy      RU  68.7500  161.3000     33.80        61         100
# 9  Punta Arenas      CL -53.1500  -70.9167     46.51        57          40
#
#    Wind Speed Current Description
# 0       18.32    scattered clouds
# 1        6.33          few clouds
# 2       14.34     overcast clouds
# 3       10.36          few clouds
# 4       21.41     overcast clouds
# 5        8.05    scattered clouds
# 6       14.90           clear sky
# 7       17.18     overcast clouds
# 8        2.80     overcast clouds
# 9       35.68    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Set the output file name
city_weather_csv = "WeatherPy_database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(city_weather_csv, index_label="City_ID")
