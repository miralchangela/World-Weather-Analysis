# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# import the citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 625

# %%
# Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
import time
#Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                           "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind
                         })
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | kloulklubed
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | arraial do cabo
# Processing Record 11 of Set 1 | hay river
# Processing Record 12 of Set 1 | naze
# Processing Record 13 of Set 1 | china
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | nusaybin
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | gradinari
# Processing Record 20 of Set 1 | bambous virieux
# Processing Record 21 of Set 1 | cabo san lucas
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | bilibino
# Processing Record 24 of Set 1 | valdivia
# Processing Record 25 of Set 1 | sao jose da coroa grande
# Processing Record 26 of Set 1 | norman wells
# Processing Record 27 of Set 1 | vanavara
# Processing Record 28 of Set 1 | taltal
# Processing Record 29 of Set 1 | saskylakh
# Processing Record 30 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 1 | port elizabeth
# Processing Record 32 of Set 1 | mecca
# Processing Record 33 of Set 1 | wiarton
# Processing Record 34 of Set 1 | jiaohe
# Processing Record 35 of Set 1 | ponta do sol
# Processing Record 36 of Set 1 | bilma
# Processing Record 37 of Set 1 | dolores
# Processing Record 38 of Set 1 | bandarbeyla
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | dalnegorsk
# Processing Record 41 of Set 1 | tura
# Processing Record 42 of Set 1 | dawlatabad
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | sola
# Processing Record 45 of Set 1 | clyde river
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 1 | te anau
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | laguna
# Processing Record 2 of Set 2 | amapa
# Processing Record 3 of Set 2 | bengkulu
# Processing Record 4 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 2 | dunedin
# Processing Record 7 of Set 2 | san patricio
# Processing Record 8 of Set 2 | korla
# Processing Record 9 of Set 2 | shakawe
# Processing Record 10 of Set 2 | hasaki
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | haines junction
# Processing Record 13 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | saint george
# Processing Record 16 of Set 2 | airai
# Processing Record 17 of Set 2 | elban
# Processing Record 18 of Set 2 | cherskiy
# Processing Record 19 of Set 2 | poya
# Processing Record 20 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 2 | sao joao da barra
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | cidreira
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | aksha
# Processing Record 27 of Set 2 | okha
# Processing Record 28 of Set 2 | lagoa
# Processing Record 29 of Set 2 | turayf
# Processing Record 30 of Set 2 | saint-philippe
# Processing Record 31 of Set 2 | fairbanks
# Processing Record 32 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 2 | leningradskiy
# Processing Record 34 of Set 2 | one hundred mile house
# City not found. Skipping...
# Processing Record 35 of Set 2 | narsaq
# Processing Record 36 of Set 2 | xingyi
# Processing Record 37 of Set 2 | hirado
# Processing Record 38 of Set 2 | antalaha
# Processing Record 39 of Set 2 | provideniya
# Processing Record 40 of Set 2 | lazaro cardenas
# Processing Record 41 of Set 2 | grindavik
# Processing Record 42 of Set 2 | hilo
# Processing Record 43 of Set 2 | ponta delgada
# Processing Record 44 of Set 2 | balkanabat
# Processing Record 45 of Set 2 | vao
# Processing Record 46 of Set 2 | ancud
# Processing Record 47 of Set 2 | tezu
# Processing Record 48 of Set 2 | college
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | olafsvik
# Processing Record 1 of Set 3 | burdur
# Processing Record 2 of Set 3 | linqiong
# Processing Record 3 of Set 3 | savinka
# Processing Record 4 of Set 3 | isangel
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | vila franca do campo
# Processing Record 7 of Set 3 | saint-louis
# Processing Record 8 of Set 3 | casas grandes
# Processing Record 9 of Set 3 | dikson
# Processing Record 10 of Set 3 | erzin
# Processing Record 11 of Set 3 | eyl
# Processing Record 12 of Set 3 | ksenyevka
# City not found. Skipping...
# Processing Record 13 of Set 3 | wajid
# Processing Record 14 of Set 3 | khatanga
# Processing Record 15 of Set 3 | saraland
# Processing Record 16 of Set 3 | bethel
# Processing Record 17 of Set 3 | manicore
# Processing Record 18 of Set 3 | tarakan
# Processing Record 19 of Set 3 | saint-augustin
# Processing Record 20 of Set 3 | chara
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | caravelas
# Processing Record 23 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 24 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 3 | ulladulla
# Processing Record 26 of Set 3 | luwuk
# Processing Record 27 of Set 3 | hamilton
# Processing Record 28 of Set 3 | marystown
# Processing Record 29 of Set 3 | phnum penh
# City not found. Skipping...
# Processing Record 30 of Set 3 | shingu
# Processing Record 31 of Set 3 | half moon bay
# Processing Record 32 of Set 3 | port alfred
# Processing Record 33 of Set 3 | hithadhoo
# Processing Record 34 of Set 3 | kita
# Processing Record 35 of Set 3 | voh
# Processing Record 36 of Set 3 | guerrero negro
# Processing Record 37 of Set 3 | maningrida
# Processing Record 38 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | mahebourg
# Processing Record 41 of Set 3 | methoni
# Processing Record 42 of Set 3 | balabac
# Processing Record 43 of Set 3 | kaitangata
# Processing Record 44 of Set 3 | severo-kurilsk
# Processing Record 45 of Set 3 | manado
# Processing Record 46 of Set 3 | arrifes
# Processing Record 47 of Set 3 | chuy
# Processing Record 48 of Set 3 | alyangula
# Processing Record 49 of Set 3 | kahului
# Processing Record 50 of Set 3 | mehamn

# %%
city_data

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
WeatherPy_database = city_data_df.to_csv("WeatherPy_database.csv", index_label="City ID")
